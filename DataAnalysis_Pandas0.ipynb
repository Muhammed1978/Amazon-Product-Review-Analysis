# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammed1978/Amazon-Product-Review-Analysis/blob/main/DataAnalysis_Pandas0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Data Analysis with Pandas
#
# Objectives
#
# * In this module participants will learn how to use pandas for importing data, data cleaning  and analysis.
#
# * Students can think of Pandas as an extremely powerful version of the spreadsheet like Microsoft  Excel  with a lot of more features .
#
# * At the course , students will be able to import, clean and do various data analysis with pandas.

# %% [markdown]
# # Importing the Pandas Library
#
# To import pandas  we usually import it with its alias as pd

# %%
import pandas as pd

# %% [markdown]
# # Core components of Pandas
#
# * The two primary components of *Pandas* are the *Series and DataFrame*.
#
# * A series is eventually a column, and a *DataFrame* is a multi-dimensional table made up of a collection of *Series*.
#
# # Series
#
#     Gender             Country                          Age
#
#     Male             Nigeria                           11
#     Female           Ethiopia                          17
#     Female           Rwanda                            15 Female           Somalia                           17
#     Male             Sudan                             13
#     Female           Kenya                              11 Male             Uganda                             9
#     Female            Kenya                             18 Male              Somalia                           13
#     Female            Rwanda                            16
#
# # DataFrame
#
#     Gender           Countries                    Age
#
#     Male              Uganda                       11
#     Female            Ethiopia                     17
#     Female            Rwanda                       15
#     Female            Rwanda                       17
#     Male              Sudan                        13
#     Female            Kenya                        11
#     Male              Uganda                       9
#     Female            kenya                        14
#     Male              Somalia                      16

# %% [markdown]
# # Series and DataFrame
#
#  Panda Series
#
#  * A series is a 1-D array like object containing a sequence of values and capable of holding any data type with axis and labels or index .
#
#  * An example of a series object is one column from a DatFrame. That is, Pandas Series is formed from only an array of data.

# %% [markdown]
# # How to create Panda Series

# %%
# Example
import pandas as pd
Gender = pd.Series(['Male','Female','Female','Male','Female','Female','Female'])
Gender
# Out:
# 0      Male
# 1    Female
# 2    Female
# 3      Male
# 4    Female
# 5    Female
# 6    Female
# dtype: object

# %%
type(Gender)  # This is a pandas series type
# Out:
# pandas.core.series.Series

# %%
# example 2
country = pd.Series(['Nigeria','Ethiopia','Rwanda','Rwanda','Sudan','Kenya','Uganda','Kenya','Somalia'])
country
# Out:
# 0     Nigeria
# 1    Ethiopia
# 2      Rwanda
# 3      Rwanda
# 4       Sudan
# 5       Kenya
# 6      Uganda
# 7       Kenya
# 8     Somalia
# dtype: object

# %%
type (country)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Exercise

# %%
age = pd.Series([11,17,15,13,11,18,9,14,16])
age
# Out:
# 0    11
# 1    17
# 2    15
# 3    13
# 4    11
# 5    18
# 6     9
# 7    14
# 8    16
# dtype: int64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Pandas DataFrame
#
# * A DataFrame represents a rectangular table of data and contains an ordered collection of columns,each of which can be a different value type (integer, float, boolean,etc).
#
# * We can think of DataFrame as a bunch of series of objects put togther to share the same index.

# %% [markdown]
# # How to create a Pandas DataFrame
#
# There are many ways to create a DataFrame scratch but a great option is to create it from a dictionary.
#
# # Creating DataFrame from a Dictionary
#
# * Among the many things that can serves as input to make a Pandas DataFrame is a  dict (Dictionay).
#
# * To make a data frame from a dictionary, you will need to pass it to the DataFrame function in the data argument.

# %% [markdown]
# # Example 1
#
# DataFrame
#
#  Gender        Country         Age
#
#     Male        Uganda          11
#
#     Female     Ethiopia         17
#
#     Female     Rwanda           15
#
#     Female     Somalia          17
#
#     Male       Sudan            13
#
#     Female     Kenya            11
#
#     Male       Uganda            9
#
#     Female     Kenya            18
#
#     Male       Somalia          13
#
#     Female     Rwanda           16

# %%
# Example: Creating DataFrame
registrations_dict = {"Gender": ["Male", "Female", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
                      "Country": ["Uganda", "Ethiopia", "Rwanda", "Somalia", "Sudan", "Kenya", "Uganda", "kenya", "Somalia", "Rwanda"],
                      "Age":[11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}

registrations_dict
# Out:
# {'Gender': ['Male',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female'],
#  'Country': ['Uganda',
#   'Ethiopia',
#   'Rwanda',
#   'Somalia',
#   'Sudan',
#   'Kenya',
#   'Uganda',
#   'kenya',
#   'Somalia',
#   'Rwanda'],
#  'Age': [11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}

# %%
type(registrations_dict)
# Out:
# dict

# %% [markdown]
# And then pass the result to the pandas Dataframe constructor.

# %%
import pandas as pd
registrations_df = pd.DataFrame(registrations_dict)
registrations_df
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13
# 5  Female     Kenya   11
# 6    Male    Uganda    9
# 7  Female     kenya   18
# 8    Male   Somalia   13
# 9  Female    Rwanda   16

# %% [markdown]
# **The resulting DataFrame will have its index assigned automatically as with Series, and the columns are placed unordered .if you specify a sequence of columns, the DataFrame's will be arranged in that order.**

# %%
registrations_df = pd.DataFrame(registrations_dict, columns = ["Country", "Gender", "Age",])
registrations_df
# Out:
#     Country  Gender  Age
# 0    Uganda    Male   11
# 1  Ethiopia  Female   17
# 2    Rwanda  Female   15
# 3   Somalia  Female   17
# 4     Sudan    Male   13
# 5     Kenya  Female   11
# 6    Uganda    Male    9
# 7     kenya  Female   18
# 8   Somalia    Male   13
# 9    Rwanda  Female   16

# %% [markdown]
# # Example 2
#  This example is for Corona virus (COVID-19) report as of November 25,2020.

# %%
import pandas as pd
COVID19data = { "Country": ["Burundi","Ethiopia","Kenya","Rwanda","Somalia","Tanzania","Uganda","Sudan"],
               "Total Cases": [673, 107109, 79322, 5750, 4445, 509, 18406, 16431],
                "Total Deaths": [1, 1664, 1417, 47, 113, 21, 186, 1202],
                "Total Recovered": [575, 66575, 52974, 5241, 3412, 183, 8764, 9854,],
                "Active Cases": [97, 38871, 24931, 462, 920, 305, 9456, 5375],
                "Population": [1202914, 116082175, 54237961, 13078334, 16066789, 60399786, 46304101, 44252054]}
COVID19data_df = pd.DataFrame(COVID19data, columns = ["Country", "Total Cases", "Total Deaths", "Total Recovered", "Active Cases", "Population",])
COVID19data_df
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0   Burundi          673             1              575            97
# 1  Ethiopia       107109          1664            66575         38871
# 2     Kenya        79322          1417            52974         24931
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
# 7     Sudan        16431          1202             9854          5375
#
#    Population
# 0     1202914
# 1   116082175
# 2    54237961
# 3    13078334
# 4    16066789
# 5    60399786
# 6    46304101
# 7    44252054

# %% [markdown]
# # Class work

# %%
import pandas as pd
tv_data = {"Gender": ["Male", "Female", "Female"],
              "Views": [458, 460, 457],
              "Online":[823, 822, 824],
              "Regards": [8, 5, 5]}
tv_data_df = pd.DataFrame(tv_data, columns = ["Gender", "Views", "Online", "Regards"])
tv_data_df
# Out:
#    Gender  Views  Online  Regards
# 0    Male    458     823        8
# 1  Female    460     822        5
# 2  Female    457     824        5

# %% [markdown]
# # Viewing Your Data
#
# For a large DataFrames, we can select the first five observations or rows by using *.head()* attributes and the last five observation by using *.tail()* attribute.
#
# **Note**
#
# The essence of using *.head() and .tail()* attributes to have easy access to your data,imagine you wan to view 2 million data set at once, this will ctashe your computer.
#
# # Example 1

# %%
import pandas as pd
registrations_dict = {"Gender": ["Male", "Female", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
                      "Country": ["Uganda", "Ethiopia", "Rwanda", "Somalia", "Sudan", "Kenya", "Uganda", "kenya", "Somalia", "Rwanda"],
                      "Age":[11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}
registrations_df = pd.DataFrame(registrations_dict)
registrations_df
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13
# 5  Female     Kenya   11
# 6    Male    Uganda    9
# 7  Female     kenya   18
# 8    Male   Somalia   13
# 9  Female    Rwanda   16

# %%
registrations_df
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13
# 5  Female     Kenya   11
# 6    Male    Uganda    9
# 7  Female     kenya   18
# 8    Male   Somalia   13
# 9  Female    Rwanda   16

# %%
registrations_df.head()
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13

# %%
registrations_df.tail()
# Out:
#    Gender  Country  Age
# 5  Female    Kenya   11
# 6    Male   Uganda    9
# 7  Female    kenya   18
# 8    Male  Somalia   13
# 9  Female   Rwanda   16

# %%
registrations_df.tail(10)
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13
# 5  Female     Kenya   11
# 6    Male    Uganda    9
# 7  Female     kenya   18
# 8    Male   Somalia   13
# 9  Female    Rwanda   16

# %% [markdown]
# # Example 2
#
# Using COVID19 data sets determine the head and tail.

# %%
import pandas as pd
COVID19data = { "Country": ["Burundi","Ethiopia","Kenya","Rwanda","Somalia","Tanzania","Uganda","Sudan"],
               "Total Cases": [673, 107109, 79322, 5750, 4445, 509, 18406, 16431],
                "Total Deaths": [1, 1664, 1417, 47, 113, 21, 186, 1202],
                "Total Recovered": [575, 66575, 52974, 5241, 3412, 183, 8764, 9854,],
                "Active Cases": [97, 38871, 24931, 462, 920, 305, 9456, 5375],
                "Population": [1202914, 116082175, 54237961, 13078334, 16066789, 60399786, 46304101, 44252054]}
COVID19data_df = pd.DataFrame(COVID19data, )
COVID19data_df.head()
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0   Burundi          673             1              575            97
# 1  Ethiopia       107109          1664            66575         38871
# 2     Kenya        79322          1417            52974         24931
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
#
#    Population
# 0     1202914
# 1   116082175
# 2    54237961
# 3    13078334
# 4    16066789

# %%
COVID19data_df.head(7)
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0   Burundi          673             1              575            97
# 1  Ethiopia       107109          1664            66575         38871
# 2     Kenya        79322          1417            52974         24931
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
#
#    Population
# 0     1202914
# 1   116082175
# 2    54237961
# 3    13078334
# 4    16066789
# 5    60399786
# 6    46304101

# %%
COVID19data_df.tail()
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
# 7     Sudan        16431          1202             9854          5375
#
#    Population
# 3    13078334
# 4    16066789
# 5    60399786
# 6    46304101
# 7    44252054

# %%
COVID19data_df.tail(3)
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
# 7     Sudan        16431          1202             9854          5375
#
#    Population
# 5    60399786
# 6    46304101
# 7    44252054

# %% [markdown]
# # Getting Information about your data
#
# **.infor() Method**
#
# *.info()* attribute provides the essential details about your dataset,such as the number of rows and columms, the number of non-null values, the type of data in each column, and how much memory your DataFrame is using.

# %% [markdown]
# # Example 1

# %%
import pandas as pd
registrations_dict = {"Gender": ["Male", "Female", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
                      "Country": ["Uganda", "Ethiopia", "Rwanda", "Somalia", "Sudan", "Kenya", "Uganda", "kenya", "Somalia", "Rwanda"],
                      "Age":[11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}
registrations_df = pd.DataFrame(registrations_dict)
registrations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Gender   10 non-null     object
#  1   Country  10 non-null     object
#  2   Age      10 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %% [markdown]
# * Seeing the datatype quickly is actually quite useful in data cleaning and analyses phases.

# %% [markdown]
# # Example 2

# %%
import pandas as pd
COVID19data = { "Country": ["Burundi","Ethiopia","Kenya","Rwanda","Somalia","Tanzania","Uganda","Sudan"],
               "Total Cases": [673, 107109, 79322, 5750, 4445, 509, 18406, 16431],
                "Total Deaths": [1, 1664, 1417, 47, 113, 21, 186, 1202],
                "Total Recovered": [575, 66575, 52974, 5241, 3412, 183, 8764, 9854,],
                "Active Cases": [97, 38871, 24931, 462, 920, 305, 9456, 5375],
                "Population": [1202914, 116082175, 54237961, 13078334, 16066789, 60399786, 46304101, 44252054]}
COVID19data_df = pd.DataFrame(COVID19data)
COVID19data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          8 non-null      object
#  1   Total Cases      8 non-null      int64
#  2   Total Deaths     8 non-null      int64
#  3   Total Recovered  8 non-null      int64
#  4   Active Cases     8 non-null      int64
#  5   Population       8 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 516.0+ bytes

# %% [markdown]
# **.shape Method**
#
# Another useful attribute is *.shape* which outputs just a tuple of (rows,columns):

# %% [markdown]
# # Example 1

# %%
import pandas as pd
registrations_dict = {"Gender": ["Male", "Female", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
                      "Country": ["Uganda", "Ethiopia", "Rwanda", "Somalia", "Sudan", "Kenya", "Uganda", "kenya", "Somalia", "Rwanda"],
                      "Age":[11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}
registrations_df = pd.DataFrame(registrations_dict)
registrations_df.shape
# Out:
# (10, 3)

# %% [markdown]
#  The students registration data has 10 rows and 3 columns
#
#  **Note**
#
#  The *.shape* has no parentheses and is a simple tuple of format (rows,columns)So we have 10 rows and 3 columns in our students registration DataFrame.

# %% [markdown]
# # Example 2

# %%
import pandas as pd
COVID19data_dict = { "Country": ["Burundi","Ethiopia","Kenya","Rwanda","Somalia","Tanzania","Uganda", "Sudan"],
               "Total Cases": [673, 107109, 79322, 5750, 4445, 509, 18406, 16431],
                "Total Deaths": [1, 1664, 1417, 47, 113, 21, 186, 1202],
                "Total Recovered": [575, 66575, 52974, 5241, 3412, 183, 8764, 9854,],
                "Active Cases": [97, 38871, 24931, 462, 920, 305, 9456, 5375],
                "Population": [1202914, 116082175, 54237961, 13078334, 16066789, 60399786, 46304101, 44252054]}

COVID19data_df = pd.DataFrame(COVID19data_dict)
COVID19data_df.shape
# Out:
# (8, 6)

# %% [markdown]
# The COVID-19 has 8 rows and 6 columns
#
# **Note**
#
# It is important to note that you are going to be using *.shape* a lot when cleaning and transforming data .For example , you might filter some rows based on some criteria and then want to know quickly how many rows removed or left in the dataset.

# %% [markdown]
# # Display the Index and Columns in dataFrame.
#
# We can use *.index and .column* attribute to see the list of observations and column names in our dataFrame.

# %% [markdown]
# # Example 1
#
# Let's check the index and columns in the students registration dataFrame.

# %%
registrations_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# The observation/index is from 0 to 9. Remember Numpy,0 : 10 means 0, 1, 2,.....9.

# %%
import pandas as pd
registrations_dict = {"Gender": ["Male", "Female", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
                      "Country": ["Uganda", "Ethiopia", "Rwanda", "Somalia", "Sudan", "Kenya", "Uganda", "kenya", "Somalia", "Rwanda"],
                      "Age":[11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}
registrations_df = pd.DataFrame(registrations_dict)
registrations_df.columns
# Out:
# Index(['Gender', 'Country', 'Age'], dtype='object')

# %% [markdown]
# * The column names in the students dataframe are Country,Gender and Age.

# %% [markdown]
# # Example 2
#
# Let's check the columns in the COVID-19 DataFrame.

# %%
import pandas as pd
COVID19data = { "Country": ["Burundi","Ethiopia","Kenya","Rwanda","Somalia","Tanzania","Uganda","Sudan"],
               "Total Cases": [673, 107109, 79322, 5750, 4445, 509, 18406, 16431],
                "Total Deaths": [1, 1664, 1417, 47, 113, 21, 186, 1202],
                "Total Recovered": [575, 66575, 52974, 5241, 3412, 183, 8764, 9854,],
                "Active Cases": [97, 38871, 24931, 462, 920, 305, 9456, 5375],
                "Population": [1202914, 116082175, 54237961, 13078334, 16066789, 60399786, 46304101, 44252054]}
COVID19data_df = pd.DataFrame(COVID19data)
COVID19data_df.columns
# Out:
# Index(['Country', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Population'],
#       dtype='object')

# %% [markdown]
# The Column names in the COVID-19 data are Country, Total Deaths, Total Recovered, Active Cases, and Population.

# %% [markdown]
# # Selection and Indexing of DataFrame
#
# Let's learn the various methods to grab data from  DataFrame.

# %% [markdown]
# # Example 1
#
# Remember our students registration DataFrame

# %%
import pandas as pd
registrations_dict = {"Gender": ["Male", "Female", "Female", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
                      "Country": ["Uganda", "Ethiopia", "Rwanda", "Somalia", "Sudan", "Kenya", "Uganda", "Kenya", "Somalia", "Rwanda"],
                      "Age":[11, 17, 15, 17, 13, 11, 9, 18, 13, 16]}

registrations_df = pd.DataFrame(registrations_dict)
registrations_df
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13
# 5  Female     Kenya   11
# 6    Male    Uganda    9
# 7  Female     Kenya   18
# 8    Male   Somalia   13
# 9  Female    Rwanda   16

# %% [markdown]
#  A column in a DataFrame can be retrieved as a Series.

# %%
registrations_df["Country"]
# Out:
# 0      Uganda
# 1    Ethiopia
# 2      Rwanda
# 3     Somalia
# 4       Sudan
# 5       Kenya
# 6      Uganda
# 7       Kenya
# 8     Somalia
# 9      Rwanda
# Name: Country, dtype: object

# %%
registrations_df["Age"]
# Out:
# 0    11
# 1    17
# 2    15
# 3    17
# 4    13
# 5    11
# 6     9
# 7    18
# 8    13
# 9    16
# Name: Age, dtype: int64

# %%
registrations_df["Gender"]
# Out:
# 0      Male
# 1    Female
# 2    Female
# 3    Female
# 4      Male
# 5    Female
# 6      Male
# 7    Female
# 8      Male
# 9    Female
# Name: Gender, dtype: object

# %% [markdown]
# Another way of extracting column is by using dot and column name.
#
# * This is used when our variable name has no special character.

# %%
# Example:
COVID19data_df
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0   Burundi          673             1              575            97
# 1  Ethiopia       107109          1664            66575         38871
# 2     Kenya        79322          1417            52974         24931
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
# 7     Sudan        16431          1202             9854          5375
#
#    Population
# 0     1202914
# 1   116082175
# 2    54237961
# 3    13078334
# 4    16066789
# 5    60399786
# 6    46304101
# 7    44252054

# %%
COVID19data_df.Total cases
# Out:
#   File "/tmp/ipython-input-2081858712.py", line 1
#     COVID19data_df.Total cases
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# The above shows error because of using invalid syntax ,the correct is shown below:

# %%
COVID19data_df["Total Cases"]
# Out:
# 0       673
# 1    107109
# 2     79322
# 3      5750
# 4      4445
# 5       509
# 6     18406
# 7     16431
# Name: Total Cases, dtype: int64

# %%
# Example:
registrations_df.Age
# Out:
# 0    11
# 1    17
# 2    15
# 3    17
# 4    13
# 5    11
# 6     9
# 7    18
# 8    13
# 9    16
# Name: Age, dtype: int64

# %% [markdown]
# **Important Notice**
#
# registrations_df['Column'] works for any column name, but registrations_df.column only works when the column name is a valid Python variable name.That is, it follows Python naming convention (no space,no special character, not starting with number,etc).

# %% [markdown]
# # Selecting two or more columns in a dataFrame
#
# We pass a list of column names to select two or more columns in a dataframe.

# %% [markdown]
# # Example 1

# %%
registrations_df
# Out:
#    Gender   Country  Age
# 0    Male    Uganda   11
# 1  Female  Ethiopia   17
# 2  Female    Rwanda   15
# 3  Female   Somalia   17
# 4    Male     Sudan   13
# 5  Female     Kenya   11
# 6    Male    Uganda    9
# 7  Female     Kenya   18
# 8    Male   Somalia   13
# 9  Female    Rwanda   16

# %%
registrations_df[["Country", "Age"]]
# Out:
#     Country  Age
# 0    Uganda   11
# 1  Ethiopia   17
# 2    Rwanda   15
# 3   Somalia   17
# 4     Sudan   13
# 5     Kenya   11
# 6    Uganda    9
# 7     Kenya   18
# 8   Somalia   13
# 9    Rwanda   16

# %%
registrations_df[["Age", "Gender"]]
# Out:
#    Age  Gender
# 0   11    Male
# 1   17  Female
# 2   15  Female
# 3   17  Female
# 4   13    Male
# 5   11  Female
# 6    9    Male
# 7   18  Female
# 8   13    Male
# 9   16  Female

# %%
registrations_df[["Country", "Gender", "Age"]]
# Out:
#     Country  Gender  Age
# 0    Uganda    Male   11
# 1  Ethiopia  Female   17
# 2    Rwanda  Female   15
# 3   Somalia  Female   17
# 4     Sudan    Male   13
# 5     Kenya  Female   11
# 6    Uganda    Male    9
# 7     Kenya  Female   18
# 8   Somalia    Male   13
# 9    Rwanda  Female   16

# %% [markdown]
# # Example 2
#
# COVID19data_df # Did you remeber this dataframe?

# %%
COVID19data_df # Did you remember this dataframe
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0   Burundi          673             1              575            97
# 1  Ethiopia       107109          1664            66575         38871
# 2     Kenya        79322          1417            52974         24931
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
# 7     Sudan        16431          1202             9854          5375
#
#    Population
# 0     1202914
# 1   116082175
# 2    54237961
# 3    13078334
# 4    16066789
# 5    60399786
# 6    46304101
# 7    44252054

# %%
COVID19data_df[["Total Cases", "Total Deaths", "Total Recovered"]] # Total Cases is COVID-19 cases
# Out:
#    Total Cases  Total Deaths  Total Recovered
# 0          673             1              575
# 1       107109          1664            66575
# 2        79322          1417            52974
# 3         5750            47             5241
# 4         4445           113             3412
# 5          509            21              183
# 6        18406           186             8764
# 7        16431          1202             9854

# %%
COVID19data_df[["Country", "Population", "Total Cases"]]
#
# Out:
#     Country  Population  Total Cases
# 0   Burundi     1202914          673
# 1  Ethiopia   116082175       107109
# 2     Kenya    54237961        79322
# 3    Rwanda    13078334         5750
# 4   Somalia    16066789         4445
# 5  Tanzania    60399786          509
# 6    Uganda    46304101        18406
# 7     Sudan    44252054        16431

# %% [markdown]
# # Selection with .loc and .iloc attribute
#
# * The loc[] and iloc[] DataFrame attribute enable you to select a subset of the rows and columns from a DataFrame with NumPy -like notation using either axis labels *(df.loc[])* or *integers* *(df.iloc[])*.
#
# * The general format for both *loc[] and iloc[]* are *df.loc[row, col]* where *df* is the name of your DataFrame while the *[row, col]* specifies the row and column index of the DataFrame.Remember Python counting starts at 0, so the first row is row zero.

# %% [markdown]
# # .loc[]
#
# As a preliminary example, let's select first three rows and columns such as Country and Population by using *df.loc[]*.

# %% [markdown]
# # Example 1
#
# *df.loc[row, col]* is for selection by column label.

# %%
COVID19data_df
# Out:
#     Country  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0   Burundi          673             1              575            97
# 1  Ethiopia       107109          1664            66575         38871
# 2     Kenya        79322          1417            52974         24931
# 3    Rwanda         5750            47             5241           462
# 4   Somalia         4445           113             3412           920
# 5  Tanzania          509            21              183           305
# 6    Uganda        18406           186             8764          9456
# 7     Sudan        16431          1202             9854          5375
#
#    Population
# 0     1202914
# 1   116082175
# 2    54237961
# 3    13078334
# 4    16066789
# 5    60399786
# 6    46304101
# 7    44252054

# %%
COVID19data_df.loc[0:3, ["Country", "Population"]]
# Out:
#     Country  Population
# 0   Burundi     1202914
# 1  Ethiopia   116082175
# 2     Kenya    54237961
# 3    Rwanda    13078334
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Population'].plot(kind='hist', bins=20, title='Population')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Country').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
COVID19data_df.loc[ : , ["Country", "Total Deaths", "Population"] ]
# Out:
#     Country  Total Deaths  Population
# 0   Burundi             1     1202914
# 1  Ethiopia          1664   116082175
# 2     Kenya          1417    54237961
# 3    Rwanda            47    13078334
# 4   Somalia           113    16066789
# 5  Tanzania            21    60399786
# 6    Uganda           186    46304101
# 7     Sudan          1202    44252054

# %% [markdown]
# In example 1, we selected the first three observations and variables Country and Population.
#
# **Important note**
#
# Please note that *.loc* index position is inclusive i.e 0:5 means 0, 1, 2, 3, 4, 5. This is different from NumPy array that 0 : 5 is 0, 1 , 2, 3, 4.

# %% [markdown]
# # Example 2
#
# df.loc[row, col] is for selection by column label

# %%
COVID19data_df.loc[:, ["Country", "Total Cases"]]
# Out:
#     Country  Total Cases
# 0   Burundi          673
# 1  Ethiopia       107109
# 2     Kenya        79322
# 3    Rwanda         5750
# 4   Somalia         4445
# 5  Tanzania          509
# 6    Uganda        18406
# 7     Sudan        16431

# %% [markdown]
# We selected all the observations (:)  and columns Country and COVID-19 Total Cases.

# %% [markdown]
# # .iloc[]
#
# *df.iloc[row, col]* is for selction by column index or position. First, let us see the column index by using .*columns* attribute.

# %%
COVID19data_df.columns
# Out:
# Index(['Country', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Population'],
#       dtype='object')
